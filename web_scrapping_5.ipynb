# %% [markdown]
# <a href="https://colab.research.google.com/github/anujv4312-stack/100_days_of_ML/blob/main/web_scrapping_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# **code not working do it later**
